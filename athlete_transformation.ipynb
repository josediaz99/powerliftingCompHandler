# %% [markdown]
# # transforming athlete csv file
# ---
# - processing using pandas
# - processing through csv methods and pickle transformation

# %%
import pandas as pd
import csv
import pickle

# %% [markdown]
# ### test case 1
# ---
# csv containing referee decision data

# %%
PATH = "data\open_nationals_day_2_awards_results.csv"

df = pd.read_csv(PATH)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 PATH = "data\open_nationals_day_2_awards_results.csv"
# ----> 3 df = pd.read_csv(PATH)
#       4 df.head()
#
# File c:\Users\josed\anaconda3\envs\ironCrawler\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\josed\anaconda3\envs\ironCrawler\Lib\site-packages\pandas\io\parsers\readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File c:\Users\josed\anaconda3\envs\ironCrawler\Lib\site-packages\pandas\io\parsers\readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File c:\Users\josed\anaconda3\envs\ironCrawler\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:215, in CParserWrapper.read(self, nrows)
#     213 try:
#     214     if self.low_memory:
# --> 215         chunks = self._reader.read_low_memory(nrows)
#     216         # destructive to chunks
#     217         data = _concatenate_chunks(chunks, self.names)
#
# File pandas/_libs/parsers.pyx:832, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:897, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:868, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:885, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2084, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 76 fields in line 4, saw 81

# %% [markdown]
# ---
# - issue: csv has values with delimeter within the value
# - decision: using the sep perameter to seporate data without the ,
# - status: pending
# - group: data transformation
# - assumptions: using pandas "sep" parameter to be able to obtain values through different sepration - method
# - constraint: \t might not fix the issue
# - position: using pandas to be able to view data still might improve the transformation methods compared to other methods
# - implications: data has "," inside of values as well as not meeting first normal form standards

# %%
PATH = "data\open_nationals_day_2_awards_results.csv"

df = pd.read_csv(
    PATH,
    sep="\t",
)

df.head()
# Out:
#   Name                , "Gender", "Raw/Equipped", "Team", "Lot", "State/Province", "Country", "Platform", "Session", "Flight", "Awards Division" , "Body Weight (kg)", "Weight Class", "Wilks Coef"        , "Exact Age", "Division Based Age", "Age Coef", "Squat 1", "Squat 2", "Squat 3", "Best Squat", "Bench 1", "Bench 2", "Bench 3", "Best Bench", "Subtotal", "Deadlift 1", "Deadlift 2", "Deadlift 3", "Best Deadlift", "Total", "Dots Points"       , "Dots & Age Points" , "Wilks Points"      , "Age Points"        , "Wilks & Age Points", "IPF Points"        , "IPF & Age Points"  , "Glossbrenner Points", "Glossbrenner & Age Points", "Schwartz Malone Points", "Schwartz Malone & Age Points", "Place", "S1LRef"  , "S1HRef"  , "S1RRef"           , "S2LRef"     , "S2HRef"     , "S2RRef"     , "S3LRef"     , "S3HRef"     , "S3RRef"     , "B1LRef"     , "B1HRef"   , "B1RRef"     , "B2LRef"     , "B2HRef"     , "B2RRef"     , "B3LRef"     , "B3HRef"           , "B3RRef"     , "D1LRef"     , "D1HRef"     , "D1RRef"     , "D2LRef"     , "D2HRef"     , "D2RRef"     , "D3LRef"     , "D3HRef"     , "D3RRef"
# 0  Meghan Scanlon      , "FEMALE", "RAW"         ...
# 1  Daisy Arreola Garcia, "FEMALE", "RAW"         ...
# 2  Hannah Peterson     , "FEMALE", "RAW"         ...
# 3  Sydney Hunter       , "FEMALE", "RAW"         ...
# 4  Maggie Stout        , "FEMALE", "RAW"         ...

# %%
df.columns
# Out:
# Index(['Name                , "Gender", "Raw/Equipped", "Team", "Lot", "State/Province", "Country", "Platform", "Session", "Flight", "Awards Division" , "Body Weight (kg)", "Weight Class", "Wilks Coef"        , "Exact Age", "Division Based Age", "Age Coef", "Squat 1", "Squat 2", "Squat 3", "Best Squat", "Bench 1", "Bench 2", "Bench 3", "Best Bench", "Subtotal", "Deadlift 1", "Deadlift 2", "Deadlift 3", "Best Deadlift", "Total", "Dots Points"       , "Dots & Age Points" , "Wilks Points"      , "Age Points"        , "Wilks & Age Points", "IPF Points"        , "IPF & Age Points"  , "Glossbrenner Points", "Glossbrenner & Age Points", "Schwartz Malone Points", "Schwartz Malone & Age Points", "Place", "S1LRef"  , "S1HRef"  , "S1RRef"           , "S2LRef"     , "S2HRef"     , "S2RRef"     , "S3LRef"     , "S3HRef"     , "S3RRef"     , "B1LRef"     , "B1HRef"   , "B1RRef"     , "B2LRef"     , "B2HRef"     , "B2RRef"     , "B3LRef"     , "B3HRef"           , "B3RRef"     , "D1LRef"     , "D1HRef"     , "D1RRef"     , "D2LRef"     , "D2HRef"     , "D2RRef"     , "D3LRef"     , "D3HRef"     , "D3RRef"'], dtype='str')

# %%
df.columns.str.split(',')[0]
# Out:
# ['Name                ',
#  ' "Gender"',
#  ' "Raw/Equipped"',
#  ' "Team"',
#  ' "Lot"',
#  ' "State/Province"',
#  ' "Country"',
#  ' "Platform"',
#  ' "Session"',
#  ' "Flight"',
#  ' "Awards Division" ',
#  ' "Body Weight (kg)"',
#  ' "Weight Class"',
#  ' "Wilks Coef"        ',
#  ' "Exact Age"',
#  ' "Division Based Age"',
#  ' "Age Coef"',
#  ' "Squat 1"',
#  ' "Squat 2"',
#  ' "Squat 3"',
#  ' "Best Squat"',
#  ' "Bench 1"',
#  ' "Bench 2"',
#  ' "Bench 3"',
#  ' "Best Bench"',
#  ' "Subtotal"',
#  ' "Deadlift 1"',
#  ' "Deadlift 2"',
#  ' "Deadlift 3"',
#  ' "Best Deadlift"',
#  ' "Total"',
#  ' "Dots Points"       ',
#  ' "Dots & Age Points" ',
#  ' "Wilks Points"      ',
#  ' "Age Points"        ',
#  ' "Wilks & Age Points"',
#  ' "IPF Points"        ',
#  ' "IPF & Age Points"  ',
#  ' "Glossbrenner Points"',
#  ' "Glossbrenner & Age Points"',
#  ' "Schwartz Malone Points"',
#  ' "Schwartz Malone & Age Points"',
#  ' "Place"',
#  ' "S1LRef"  ',
#  ' "S1HRef"  ',
#  ' "S1RRef"           ',
#  ' "S2LRef"     ',
#  ' "S2HRef"     ',
#  ' "S2RRef"     ',
#  ' "S3LRef"     ',
#  ' "S3HRef"     ',
#  ' "S3RRef"     ',
#  ' "B1LRef"     ',
#  ' "B1HRef"   ',
#  ' "B1RRef"     ',
#  ' "B2LRef"     ',
#  ' "B2HRef"     ',
#  ' "B2RRef"     ',
#  ' "B3LRef"     ',
#  ' "B3HRef"           ',
#  ' "B3RRef"     ',
#  ' "D1LRef"     ',
#  ' "D1HRef"     ',
#  ' "D1RRef"     ',
#  ' "D2LRef"     ',
#  ' "D2HRef"     ',
#  ' "D2RRef"     ',
#  ' "D3LRef"     ',
#  ' "D3HRef"     ',
#  ' "D3RRef"']

# %%
df.info
# Out:
# <bound method DataFrame.info of    Name                , "Gender", "Raw/Equipped", "Team", "Lot", "State/Province", "Country", "Platform", "Session", "Flight", "Awards Division" , "Body Weight (kg)", "Weight Class", "Wilks Coef"        , "Exact Age", "Division Based Age", "Age Coef", "Squat 1", "Squat 2", "Squat 3", "Best Squat", "Bench 1", "Bench 2", "Bench 3", "Best Bench", "Subtotal", "Deadlift 1", "Deadlift 2", "Deadlift 3", "Best Deadlift", "Total", "Dots Points"       , "Dots & Age Points" , "Wilks Points"      , "Age Points"        , "Wilks & Age Points", "IPF Points"        , "IPF & Age Points"  , "Glossbrenner Points", "Glossbrenner & Age Points", "Schwartz Malone Points", "Schwartz Malone & Age Points", "Place", "S1LRef"  , "S1HRef"  , "S1RRef"           , "S2LRef"     , "S2HRef"     , "S2RRef"     , "S3LRef"     , "S3HRef"     , "S3RRef"     , "B1LRef"     , "B1HRef"   , "B1RRef"     , "B2LRef"     , "B2HRef"     , "B2RRef"     , "B3LRef"     , "B3HRef"           , "B3RRef"     , "D1LRef"     , "D1HRef"     , "D1RRef"     , "D2LRef"     , "D2HRef"     , "D2RRef"     , "D3LRef"     , "D3HRef"     , "D3RRef"
# 0   Meghan Scanlon      , "FEMALE", "RAW"         ...
# 1   Daisy Arreola Garcia, "FEMALE", "RAW"         ...
# 2   Hannah Peterson     , "FEMALE", "RAW"         ...
# 3   Sydney Hunter       , "FEMALE", "RAW"         ...
# 4   Maggie Stout        , "FEMALE", "RAW"         ...
# ..                                                ...
# 60  Benjamin Mathews    , "MALE"  , "RAW"         ...
# 61  Brandon Flores      , "MALE"  , "RAW"         ...
# 62  Manasseh Endwarrior , "MALE"  , "RAW"         ...
# 63  Hao Cheng           , "MALE"  , "RAW"         ...
# 64  Charles Hammonds    , "MALE"  , "RAW"         ...
#
# [65 rows x 1 columns]>

# %%
SAMPLE = df['Name                , "Gender", "Raw/Equipped", "Team", "Lot", "State/Province", "Country", "Platform", "Session", "Flight", "Awards Division" , "Body Weight (kg)", "Weight Class", "Wilks Coef"        , "Exact Age", "Division Based Age", "Age Coef", "Squat 1", "Squat 2", "Squat 3", "Best Squat", "Bench 1", "Bench 2", "Bench 3", "Best Bench", "Subtotal", "Deadlift 1", "Deadlift 2", "Deadlift 3", "Best Deadlift", "Total", "Dots Points"       , "Dots & Age Points" , "Wilks Points"      , "Age Points"        , "Wilks & Age Points", "IPF Points"        , "IPF & Age Points"  , "Glossbrenner Points", "Glossbrenner & Age Points", "Schwartz Malone Points", "Schwartz Malone & Age Points", "Place", "S1LRef"  , "S1HRef"  , "S1RRef"           , "S2LRef"     , "S2HRef"     , "S2RRef"     , "S3LRef"     , "S3HRef"     , "S3RRef"     , "B1LRef"     , "B1HRef"   , "B1RRef"     , "B2LRef"     , "B2HRef"     , "B2RRef"     , "B3LRef"     , "B3HRef"           , "B3RRef"     , "D1LRef"     , "D1HRef"     , "D1RRef"     , "D2LRef"     , "D2HRef"     , "D2RRef"     , "D3LRef"     , "D3HRef"     , "D3RRef"'].replace(' ','').replace('"','')

# %%
SAMPLE.head
# Out:
# <bound method NDFrame.head of 0     Meghan Scanlon      , "FEMALE", "RAW"         ...
# 1     Daisy Arreola Garcia, "FEMALE", "RAW"         ...
# 2     Hannah Peterson     , "FEMALE", "RAW"         ...
# 3     Sydney Hunter       , "FEMALE", "RAW"         ...
# 4     Maggie Stout        , "FEMALE", "RAW"         ...
#                             ...
# 60    Benjamin Mathews    , "MALE"  , "RAW"         ...
# 61    Brandon Flores      , "MALE"  , "RAW"         ...
# 62    Manasseh Endwarrior , "MALE"  , "RAW"         ...
# 63    Hao Cheng           , "MALE"  , "RAW"         ...
# 64    Charles Hammonds    , "MALE"  , "RAW"         ...
# Name: Name                , "Gender", "Raw/Equipped", "Team", "Lot", "State/Province", "Country", "Platform", "Session", "Flight", "Awards Division" , "Body Weight (kg)", "Weight Class", "Wilks Coef"        , "Exact Age", "Division Based Age", "Age Coef", "Squat 1", "Squat 2", "Squat 3", "Best Squat", "Bench 1", "Bench 2", "Bench 3", "Best Bench", "Subtotal", "Deadlift 1", "Deadlift 2", "Deadlift 3", "Best Deadlift", "Total", "Dots Points"       , "Dots & Age Points" , "Wilks Points"      , "Age Points"        , "Wilks & Age Points", "IPF Points"        , "IPF & Age Points"  , "Glossbrenner Points", "Glossbrenner & Age Points", "Schwartz Malone Points", "Schwartz Malone & Age Points", "Place", "S1LRef"  , "S1HRef"  , "S1RRef"           , "S2LRef"     , "S2HRef"     , "S2RRef"     , "S3LRef"     , "S3HRef"     , "S3RRef"     , "B1LRef"     , "B1HRef"   , "B1RRef"     , "B2LRef"     , "B2HRef"     , "B2RRef"     , "B3LRef"     , "B3HRef"           , "B3RRef"     , "D1LRef"     , "D1HRef"     , "D1RRef"     , "D2LRef"     , "D2HRef"     , "D2RRef"     , "D3LRef"     , "D3HRef"     , "D3RRef", Length: 65, dtype: str>

# %%
# standardizing columns to make them easier to work with
COLS = df.columns.str.replace(' ', '').str.replace('"', '').str.split(',')[0]
print(COLS)
# Out:
# ['Name', 'Gender', 'Raw/Equipped', 'Team', 'Lot', 'State/Province', 'Country', 'Platform', 'Session', 'Flight', 'AwardsDivision', 'BodyWeight(kg)', 'WeightClass', 'WilksCoef', 'ExactAge', 'DivisionBasedAge', 'AgeCoef', 'Squat1', 'Squat2', 'Squat3', 'BestSquat', 'Bench1', 'Bench2', 'Bench3', 'BestBench', 'Subtotal', 'Deadlift1', 'Deadlift2', 'Deadlift3', 'BestDeadlift', 'Total', 'DotsPoints', 'Dots&AgePoints', 'WilksPoints', 'AgePoints', 'Wilks&AgePoints', 'IPFPoints', 'IPF&AgePoints', 'GlossbrennerPoints', 'Glossbrenner&AgePoints', 'SchwartzMalonePoints', 'SchwartzMalone&AgePoints', 'Place', 'S1LRef', 'S1HRef', 'S1RRef', 'S2LRef', 'S2HRef', 'S2RRef', 'S3LRef', 'S3HRef', 'S3RRef', 'B1LRef', 'B1HRef', 'B1RRef', 'B2LRef', 'B2HRef', 'B2RRef', 'B3LRef', 'B3HRef', 'B3RRef', 'D1LRef', 'D1HRef', 'D1RRef', 'D2LRef', 'D2HRef', 'D2RRef', 'D3LRef', 'D3HRef', 'D3RRef']

# %% [markdown]
# ### transforming using pickle transformation
# ---

# %%
import csv
import pickle

csv_file = r'data\open_nationals_day_2_awards_results.csv'
pickle_file = r'data\open_nationals_day_2_awards_results.pkl'


try:
    with open(csv_file, 'r', encoding='utf-8') as f:
        reader = csv.reader(f)
        data_as_list = list(reader) # Read all data into a list

    with open(pickle_file, 'wb') as f: # Open in write binary mode
        pickle.dump(data_as_list, f)
    
    print(f"Successfully converted {csv_file} to a list and saved as {pickle_file} using built-in modules.")

except FileNotFoundError:
    print(f"Error: {csv_file} not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
df = pd.read_pickle(pickle_file)
print(df)

# %%
for x in df:
    print(x)
    print(type(x))

# %%
# TODO: convert list to dicts and input to database with proper column names and types

# %% [markdown]
# # processing data
# ---
# - issue: csv attributes arent completely understood due to the nature of lifting cast
# - decision: based on the three sample csvs pulled we will use the columns and indexing seen to retrieve data
# - group: data Loading
# - assumptions: lifting cast uses the same format for all powerlifting competitions
# - constraints: there is data names are slighly different in and due to large amount of potential athletes on the day we could be processing hundreds of athletes very often
# - position: using this format we can clean the columns so they always match despite small changes
# - implications: pythons naturally slower processing will need to rely on algorithms and optimized time complexity to efficiently process all potential athletes

# %%
SAMPLE_LIST =  SAMPLE[0].split(',')
REF_DECISION_INDEX = 42
i = 0
j = 0

DATA = {}
while i < len(COLS):
    if i > REF_DECISION_INDEX and SAMPLE_LIST[j] == 'bad':
        j += 1
        continue
    print(COLS[i], " | ", SAMPLE_LIST[j])
    DATA[COLS[i]] = SAMPLE_LIST[j]
    i += 1
    j += 1
# Out:
# Name  |  Meghan Scanlon
# Gender  |   "FEMALE"
# Raw/Equipped  |   "RAW"
# Team  |   ""
# Lot  |   "141"
# State/Province  |   "MA"
# Country  |
# Platform  |   "2"
# Session  |   "4"
# Flight  |   "A"
# AwardsDivision  |   "Women's Raw Open"
# BodyWeight(kg)  |   "62.74"
# WeightClass  |   "63"
# WilksCoef  |   "1.0773287692485658"
# ExactAge  |   "37"
# DivisionBasedAge  |   "38"
# AgeCoef  |   "1"
# Squat1  |   "182.5"
# Squat2  |   "195"
# Squat3  |   "203.5"
# BestSquat  |   "203.5"
# Bench1  |   "132.5"
# Bench2  |   "137.5"
# Bench3  |   "-143.5"
# BestBench  |   "137.5"
# Subtotal  |   "341"
# Deadlift1  |   "192.5"
# Deadlift2  |   "212.5"
# Deadlift3  |   "222.5"
# BestDeadlift  |   "222.5"
# Total  |   "563.5"
# DotsPoints  |   "607.5830565145685"
# Dots&AgePoints  |   "607.5830565145685"
# WilksPoints  |   "607.0747614715668"
# AgePoints  |   "563.5"
# Wilks&AgePoints  |   "607.0747614715668"
# IPFPoints  |   "123.61407916828898"
# IPF&AgePoints  |   "123.61407916828898"
# GlossbrennerPoints  |   "536.942245"
# Glossbrenner&AgePoints  |   "536.942245"
# SchwartzMalonePoints  |   "467.8177"
# SchwartzMalone&AgePoints  |   "467.8177"
# Place  |   "1"
# S1LRef  |   "good"
# S1HRef  |   "good"
# S1RRef  |   "good"
# S2LRef  |   "good"
# S2HRef  |   "good"
# S2RRef  |   "good"
# S3LRef  |   "good"
# S3HRef  |   "good"
# S3RRef  |   "good"
# B1LRef  |   "good"
# B1HRef  |   "bad
# B1RRef  |   red"
# B2LRef  |   "good"
# B2HRef  |   "bad
# B2RRef  |   blue"
# B3LRef  |   "good"
# B3HRef  |   "good"
# B3RRef  |   "bad
# D1LRef  |   yellow"
# D1HRef  |   "bad
# D1RRef  |   yellow"
# D2LRef  |   "bad
# D2HRef  |   yellow"
# D2RRef  |   "good"
# D3LRef  |   "bad
# D3HRef  |   yellow"
# D3RRef  |   "good"

# %%
print(DATA)
# Out:
# {'Name': 'MeghanScanlon', 'Gender': 'FEMALE', 'Raw/Equipped': 'RAW', 'Team': '', 'Lot': '141', 'State/Province': 'MA', 'Country': '', 'Platform': '2', 'Session': '4', 'Flight': 'A', 'AwardsDivision': "Women'sRawOpen", 'BodyWeight(kg)': '62.74', 'WeightClass': '63', 'WilksCoef': '1.0773287692485658', 'ExactAge': '37', 'DivisionBasedAge': '38', 'AgeCoef': '1', 'Squat1': '182.5', 'Squat2': '195', 'Squat3': '203.5', 'BestSquat': '203.5', 'Bench1': '132.5', 'Bench2': '137.5', 'Bench3': '-143.5', 'BestBench': '137.5', 'Subtotal': '341', 'Deadlift1': '192.5', 'Deadlift2': '212.5', 'Deadlift3': '222.5', 'BestDeadlift': '222.5', 'Total': '563.5', 'DotsPoints': '607.5830565145685', 'Dots&AgePoints': '607.5830565145685', 'WilksPoints': '607.0747614715668', 'AgePoints': '563.5', 'Wilks&AgePoints': '607.0747614715668', 'IPFPoints': '123.61407916828898', 'IPF&AgePoints': '123.61407916828898', 'GlossbrennerPoints': '536.942245', 'Glossbrenner&AgePoints': '536.942245', 'SchwartzMalonePoints': '467.8177', 'SchwartzMalone&AgePoints': '467.8177', 'Place': '1', 'S1LRef': 'good', 'S1HRef': 'good', 'S1RRef': 'good', 'S2LRef': 'good', 'S2HRef': 'good', 'S2RRef': 'good', 'S3LRef': 'good', 'S3HRef': 'good', 'S3RRef': 'good', 'B1LRef': 'good', 'B1HRef': 'red', 'B1RRef': 'good', 'B2LRef': 'blue', 'B2HRef': 'good', 'B2RRef': 'good', 'B3LRef': 'yellow', 'B3HRef': 'yellow', 'B3RRef': 'yellow', 'D1LRef': 'good', 'D1HRef': 'yellow', 'D1RRef': 'good', 'D2LRef': 'good', 'D2HRef': 'good', 'D2RRef': 'good', 'D3LRef': 'good', 'D3HRef': 'good', 'D3RRef': 'good'}

# %% [markdown]
# # Database management
# ---
# - issue: planning to move database to free tier cloud service which will require minimal date storage
# - decision: we will only store enough data that can help us calculate whats needed as shown in ER_diagram
# - group: data Loading
# - assumptions: database will allow for enough read writes for all competitions throughout the day (72kb/ large meet)
# - constraints: 1GB storage 10GB egress 500mg file storage
# - position: can also set up a local database so people can store data on their own which would allow for me not to worry about competitions outside of the selected
# - implications: need to set up cloud based database, create ER_diagram, create competition data on server side to minimize database storage

# %%
ATTRIBUTES = {'Name', 'Gender', 'Raw/Equipped', 
              'Team', 'Session', 'Flight', 
              'AwardsDivision', 'BodyWeight(kg)', 
              'WeightClass', 'ExactAge', 
              'BestSquat', 'BestBench', 'BestDeadlift'}

# %% [markdown]
# # athlete object
# ---
# - issue: unsure if best_lifts are updated as competition progresses or once all three are complete
# - decision: process data by choosing the larger successful lift
# - group: data Loading
# - assumptions: failed lifts seem to be stored as negative numbers so choosing the largest of the 4 should be good using the max function
# - constrains: this might be slow when running frequent scrapes
# - position: once best_lift behavior is confirmed we can optimize to the behavior
# - implication: due to potential size of competition data keeping time complexity low is a priority

# %%
SAMPLE_LIST =  SAMPLE.split(',')
REF_DECISION_INDEX = 42
i = 0
j = 0

DATA = {}
while i < len(COLS):
    if i > REF_DECISION_INDEX and SAMPLE_LIST[j] == 'bad':
        j += 1
        continue
    if COLS[i] in ATTRIBUTES:
        DATA[COLS[i]] = SAMPLE_LIST[j]
    i += 1
    j += 1

print(DATA)
# Out:
# {'Name': 'MeghanScanlon', 'Gender': 'FEMALE', 'Raw/Equipped': 'RAW', 'Team': '', 'Session': '4', 'Flight': 'A', 'AwardsDivision': "Women'sRawOpen", 'BodyWeight(kg)': '62.74', 'WeightClass': '63', 'ExactAge': '37', 'BestSquat': '203.5', 'BestBench': '137.5', 'BestDeadlift': '222.5'}

# %%
def Extract_Athlete(df:pd.DataFrame, path):
    CSV_HEAD = [# personal data
                'Name', 'Gender', 'Raw/Equipped',
                'Team', 'Lot', 'State/Province', 'Country',
                'Platform', 'Session', 'Flight', 'AwardsDivision', 
                'BodyWeight(kg)', 'WeightClass', 'WilksCoef', 
                'ExactAge', 'DivisionBasedAge', 'AgeCoef', 
                # attempted loads
                'Squat1', 'Squat2', 'Squat3', 'BestSquat', 
                'Bench1', 'Bench2', 'Bench3', 'BestBench', 
                'Subtotal', 'Deadlift1', 'Deadlift2', 
                'Deadlift3', 'BestDeadlift', 'Total', 
                # competition scores
                'DotsPoints', 'Dots&AgePoints', 'WilksPoints', 
                'AgePoints', 'Wilks&AgePoints', 'IPFPoints', 
                'IPF&AgePoints', 'GlossbrennerPoints', 
                'Glossbrenner&AgePoints', 'SchwartzMalonePoints', 
                'SchwartzMalone&AgePoints', 'Place', 
                # referee decisions
                'S1LRef', 'S1HRef', 'S1RRef', 'S2LRef', 'S2HRef', 'S2RRef', 'S3LRef', 'S3HRef', 'S3RRef', 
                'B1LRef', 'B1HRef', 'B1RRef', 'B2LRef', 'B2HRef', 'B2RRef', 'B3LRef', 'B3HRef', 'B3RRef', 
                'D1LRef', 'D1HRef', 'D1RRef', 'D2LRef', 'D2HRef', 'D2RRef', 'D3LRef', 'D3HRef', 'D3RRef']
    try:
        df = pd.read_csv(path)
    except:
        # the csv stores , inside referee decisions so we extract manualy
        df = pd.read_csv(path, sep="\t")

# %%
# csv doesnt need any transfomation when the competitions is being 
# scraped ahead of time due to lack of referee decisions

pd2 = pd.read_csv(r'C:\Users\josed\projects\powerliftingCompHandler\notebooks\data\2026_usapl_texas_high_school_state_championships_awards_results.csv')
pd2.head
# Out:
# <bound method NDFrame.head of                  Name  Gender Raw/Equipped                 Team  Lot  \
# 0       Naudya Garcia  FEMALE     EQUIPPED  Lehman Powerlifting  112
# 1      Ariza Guerrero  FEMALE     EQUIPPED  Lehman Powerlifting  116
# 2     Claire Schorsch  FEMALE          RAW           Jourdanton  121
# 3       Alexa Parrish  FEMALE          RAW           Jourdanton  113
# 4    Catherine Wooten  FEMALE          RAW                  NaN  118
# 5       Jaylee Miller  FEMALE          RAW       Vista Ridge HS  119
# 6        Kristy Yepez  FEMALE          RAW       Vista Ridge HS  122
# 7          Amaya Loza  FEMALE          RAW           Jourdanton  117
# 8       Caydee Herbst  FEMALE          RAW           Jourdanton  110
# 9       Emelia Garcia  FEMALE          RAW           Jourdanton  115
# 10      Analise Garza  FEMALE          RAW           Jourdanton  123
# 11   Hayden Schuchman  FEMALE          RAW           Jourdanton  120
# 12    Nyellie Alcorta  FEMALE          RAW           Jourdanton  111
# 13     Lianna Olenich  FEMALE          RAW       Vista Ridge HS  114
# 14     Tavion Feagiai    MALE          RAW       Vista Ridge HS  320
# 15         Paul Lopez    MALE          RAW           Jourdanton  214
# 16      Dylan Compere    MALE          RAW                  NaN  218
# 17    Quentin Trevino    MALE          RAW           Jourdanton  219
# 18       Zander Hance    MALE          RAW           Jourdanton  215
# 19      Zak Henderson    MALE          RAW                  NaN  211
# 20  Alexander Schmeis    MALE          RAW                  NaN  212
# 21        Ayman Lough    MALE          RAW       Vista Ridge HS  217
# 22  Sebastian Hoffman    MALE          RAW                  NaN  220
# 23     Colton Parrish    MALE          RAW           Jourdanton  221
# 24     Kairo Martinez    MALE          RAW           Jourdanton  213
# 25    Yeicob Calderon    MALE          RAW                  NaN  216
# 26      Eric Gonzales    MALE          RAW           Jourdanton  316
# 27      Abel Gallegos    MALE          RAW           Jourdanton  319
# 28      Gabe Guerrero    MALE          RAW           Jourdanton  313
# 29     Tyrell Feagiai    MALE          RAW       Vista Ridge HS  314
# 30     Benjamin Davis    MALE          RAW        Davis Academy  315
# 31       Brendan Ruff    MALE          RAW       Terrell Tigers  312
# 32      Rafe Brewster    MALE          RAW       Vista Ridge HS  311
# 33       Alek Hillman    MALE          RAW           Jourdanton  210
# 34      Landen Chavez    MALE          RAW           Jourdanton  310
# 35        Ethan Shenk    MALE          RAW       Vista Ridge HS  317
# 36   Caleb Green-Ondo    MALE          RAW           Jourdanton  318
# 37     Tyrone Feagiai    MALE          RAW       Vista Ridge HS  321
# 38        Derek Solis    MALE          RAW           Jourdanton  322
#
#    State/Province Country  Platform  Session Flight  ... B3RRef  D1LRef  \
# 0              TX      US         1        1      A  ...    NaN     NaN
# 1              TX      US         1        1      A  ...    NaN     NaN
# 2             NaN     NaN         1        1      A  ...    NaN     NaN
# 3             NaN     NaN         1        1      A  ...    NaN     NaN
# 4              TX      US         1        1      A  ...    NaN     NaN
# 5              TX      US         1        1      A  ...    NaN     NaN
# 6              TX      US         1        1      A  ...    NaN     NaN
# 7             NaN     NaN         1        1      A  ...    NaN     NaN
# 8             NaN     NaN         1        1      A  ...    NaN     NaN
# 9             NaN     NaN         1        1      A  ...    NaN     NaN
# 10            NaN     NaN         1        1      A  ...    NaN     NaN
# 11            NaN     NaN         1        1      A  ...    NaN     NaN
# 12            NaN     NaN         1        1      A  ...    NaN     NaN
# 13             TX      US         1        1      A  ...    NaN     NaN
# 14             TX      US         1        1      C  ...    NaN     NaN
# 15            NaN     NaN         1        1      B  ...    NaN     NaN
# 16             TX      US         1        1      B  ...    NaN     NaN
# 17            NaN     NaN         1        1      B  ...    NaN     NaN
# 18            NaN     NaN         1        1      B  ...    NaN     NaN
# 19             TX      US         1        1      B  ...    NaN     NaN
# 20             TX     NaN         1        1      B  ...    NaN     NaN
# 21             TX      US         1        1      B  ...    NaN     NaN
# 22             TX      US         1        1      B  ...    NaN     NaN
# 23            NaN     NaN         1        1      B  ...    NaN     NaN
# 24            NaN     NaN         1        1      B  ...    NaN     NaN
# 25             TX      US         1        1      B  ...    NaN     NaN
# 26            NaN     NaN         1        1      C  ...    NaN     NaN
# 27            NaN     NaN         1        1      C  ...    NaN     NaN
# 28            NaN     NaN         1        1      C  ...    NaN     NaN
# 29             TX      US         1        1      C  ...    NaN     NaN
# 30             TX      US         1        1      C  ...    NaN     NaN
# 31             TX      US         1        1      C  ...    NaN     NaN
# 32             TX      US         1        1      C  ...    NaN     NaN
# 33            NaN     NaN         1        1      B  ...    NaN     NaN
# 34            NaN     NaN         1        1      C  ...    NaN     NaN
# 35             TX      US         1        1      C  ...    NaN     NaN
# 36            NaN     NaN         1        1      C  ...    NaN     NaN
# 37             TX      US         1        1      C  ...    NaN     NaN
# 38            NaN     NaN         1        1      C  ...    NaN     NaN
#
#    D1HRef  D1RRef  D2LRef  D2HRef  D2RRef  D3LRef  D3HRef  D3RRef
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 12    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 13    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 14    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 15    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 16    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 17    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 18    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 19    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 21    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 22    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 23    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 24    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 25    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 26    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 27    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 28    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 29    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 30    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 31    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 32    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 33    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 34    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 35    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 36    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 37    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 38    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [39 rows x 70 columns]>
